# %%
import numpy as np

# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.constraints import max_norm

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape the data for CNN input
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Define the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(28, 28, 1), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=128)

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)

# Choose a sample image from the test set
sample_image = x_test[0]
sample_image = np.expand_dims(sample_image, axis=0)  # Add batch dimension

# Get the output of each layer in the model
layer_outputs = [layer.output for layer in model.layers]
activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(sample_image)

# Visualize the output of each convolutional layer
for i, activation in enumerate(activations):
    if isinstance(model.layers[i], Conv2D):
        print(f"Convolutional Layer {i}:")
        print(activation.shape)  # Print the shape of the output tensor
    elif isinstance(model.layers[i], MaxPooling2D):
        print(f"Pooling Layer {i}:")
        print(activation.shape)  # Print the shape of the output tensor
# Out:
# Epoch 1/10
# 469/469 [==============================] - 235s 496ms/step - loss: 0.2687 - accuracy: 0.9153 - val_loss: 0.0525 - val_accuracy: 0.9815
# Epoch 2/10
# 469/469 [==============================] - 231s 492ms/step - loss: 0.0887 - accuracy: 0.9746 - val_loss: 0.0360 - val_accuracy: 0.9888
# Epoch 3/10
# 469/469 [==============================] - 231s 493ms/step - loss: 0.0610 - accuracy: 0.9820 - val_loss: 0.0286 - val_accuracy: 0.9906
# Epoch 4/10
# 469/469 [==============================] - 227s 484ms/step - loss: 0.0498 - accuracy: 0.9856 - val_loss: 0.0217 - val_accuracy: 0.9929
# Epoch 5/10
# 469/469 [==============================] - 230s 489ms/step - loss: 0.0424 - accuracy: 0.9877 - val_loss: 0.0205 - val_accuracy: 0.9942
# Epoch 6/10
# 469/469 [==============================] - 228s 487ms/step - loss: 0.0373 - accuracy: 0.9888 - val_loss: 0.0223 - val_accuracy: 0.9929
# Epoch 7/10
# 469/469 [==============================] - 228s 484ms/step - loss: 0.0324 - accuracy: 0.9901 - val_loss: 0.0227 - val_accuracy: 0.9923
# Epoch 8/10
# 469/469 [==============================] - 228s 486ms/step - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.0197 - val_accuracy: 0.9934
# Epoch 9/10
# 469/469 [==============================] - 227s 485ms/step - loss: 0.0260 - accuracy: 0.9921 - val_loss: 0.0200 - val_accuracy: 0.9930
# Epoch 10/10
# 469/469 [==============================] - 231s 493ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0182 - val_accuracy: 0.9944
# 313/313 [==============================] - 10s 32ms/step - loss: 0.0182 - accuracy: 0.9944
# Test Accuracy: 0.9944000244140625
# 1/1 [==============================] - 0s 110ms/step
# Convolutional Layer 0:
# (1, 28, 28, 32)
# Convolutional Layer 2:
# (1, 28, 28, 32)
# Pooling Layer 3:
# (1, 14, 14, 32)
# Convolutional Layer 4:
# (1, 14, 14, 64)
# Convolutional Layer 6:
# (1, 14, 14, 64)
# Pooling Layer 7:
# (1, 7, 7, 64)

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define the CNN model
model = Sequential([
  Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
  MaxPooling2D((2, 2)),
  Conv2D(64, (3, 3), activation='relu'),
  MaxPooling2D((2, 2)),
  Flatten(),
  Dense(128, activation='relu'),
  Dense(10, activation='softmax')
])

# Compile the model
model.compile(
  optimizer='adam',
  loss='sparse_categorical_crossentropy',
  metrics=['accuracy']
)

# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)

# Make predictions on new data
predictions = model.predict(x_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.1336 - accuracy: 0.9600
# Epoch 2/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0444 - accuracy: 0.9862
# Epoch 3/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0301 - accuracy: 0.9905
# Epoch 4/10
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0226 - accuracy: 0.9925
# Epoch 5/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0156 - accuracy: 0.9950
# Epoch 6/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0132 - accuracy: 0.9952
# Epoch 7/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0094 - accuracy: 0.9967
# Epoch 8/10
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.0085 - accuracy: 0.9971
# Epoch 9/10
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0064 - accuracy: 0.9979
# Epoch 10/10
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0063 - accuracy: 0.9976
# 313/313 [==============================] - 3s 7ms/step - loss: 0.0393 - accuracy: 0.9916
# Test accuracy: 0.991599977016449
# 313/313 [==============================] - 3s 9ms/step
